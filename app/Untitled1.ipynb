# %%
import torch
import torch.nn.functional as F

# %%
t4d = torch.empty(3, 3, 4, 2)

# %%
t4d
# Out:
# tensor([[[[7.1626e-34, 9.7358e-39],
#           [2.2967e-39, 1.9881e-28],
#           [2.9626e-36, 9.8264e-39],
#           [1.8422e-34, 9.6316e-34]],
#
#          [[2.9630e-36, 4.8126e-38],
#           [3.0334e-33, 1.0745e-38],
#           [2.7556e-33, 3.0335e-33],
#           [1.9882e-28, 4.6288e-38]],
#
#          [[9.1859e-39, 5.2898e-38],
#           [1.0979e-32, 4.7398e-35],
#           [3.6686e-36, 1.7570e-31],
#           [4.2801e-38, 7.0281e-31]]],
#
#
#         [[[9.1866e-39, 5.2898e-38],
#           [2.8121e-30, 7.5836e-34],
#           [1.2774e-26, 2.7449e-33],
#           [5.2901e-38, 4.8690e-32]],
#
#          [[4.5000e-38, 2.4781e+05],
#           [3.8536e-33, 5.9159e-38],
#           [1.9413e-31, 4.5000e-38],
#           [2.7247e+17, 3.8537e-33]],
#
#          [[5.9160e-38, 7.7654e-31],
#           [4.5000e-38, 2.9959e+29],
#           [3.8538e-33, 5.9161e-38],
#           [7.9517e-28, 1.1243e-29]]],
#
#
#         [[[2.3661e-37, 1.1245e-29],
# ...

# %%
p1d = (1, 1)

# %%
F.pad(t4d, p1d, "constant", 0)
# Out:
# tensor([[[[0.0000e+00, 7.1626e-34, 9.7358e-39, 0.0000e+00],
#           [0.0000e+00, 2.2967e-39, 1.9881e-28, 0.0000e+00],
#           [0.0000e+00, 2.9626e-36, 9.8264e-39, 0.0000e+00],
#           [0.0000e+00, 1.8422e-34, 9.6316e-34, 0.0000e+00]],
#
#          [[0.0000e+00, 2.9630e-36, 4.8126e-38, 0.0000e+00],
#           [0.0000e+00, 3.0334e-33, 1.0745e-38, 0.0000e+00],
#           [0.0000e+00, 2.7556e-33, 3.0335e-33, 0.0000e+00],
#           [0.0000e+00, 1.9882e-28, 4.6288e-38, 0.0000e+00]],
#
#          [[0.0000e+00, 9.1859e-39, 5.2898e-38, 0.0000e+00],
#           [0.0000e+00, 1.0979e-32, 4.7398e-35, 0.0000e+00],
#           [0.0000e+00, 3.6686e-36, 1.7570e-31, 0.0000e+00],
#           [0.0000e+00, 4.2801e-38, 7.0281e-31, 0.0000e+00]]],
#
#
#         [[[0.0000e+00, 9.1866e-39, 5.2898e-38, 0.0000e+00],
#           [0.0000e+00, 2.8121e-30, 7.5836e-34, 0.0000e+00],
#           [0.0000e+00, 1.2774e-26, 2.7449e-33, 0.0000e+00],
# ...
